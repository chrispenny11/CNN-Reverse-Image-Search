# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= 14,9

# %%
df_comparison = pd.read_csv('./results/11.03.2020 baseline_resnet_benchmarks.csv')
display(df_comparison)

prec_compare = df_comparison[['Precision at 5', 'Precision at 10', 'Precision at 15', 'Precision at 20']].values
print(prec_compare)

time_compare = df_comparison['Average Query Time'].values
print(time_compare)
# Out:
#         Method  Vector Length  Average Query Time  Precision at 5  \
# 0  Brute Force           1000            0.273634        0.665652
# 1  Brute Force           2048            0.556166        0.550864
# 2      ANNOY 1           1000            0.000454        0.652704
# 3      ANNOY 1           2048            0.001335        0.477180
# 4     ANNOY 10           1000            0.000442        0.661848
# 5     ANNOY 10           2048            0.001369        0.518776
# 6    ANNOY 100           1000            0.001098        0.665584
# 7    ANNOY 100           2048            0.002457        0.542796
# 8   ANNOY 1000           1000            0.006947        0.665644
# 9   ANNOY 1000           2048            0.007983        0.550192
#
#    Precision at 10  Precision at 15  Precision at 20
# 0         0.623398         0.608957         0.599531
# 1         0.444532         0.389239         0.351183
# 2         0.602618         0.582169         0.567565
# ...

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[0], color = '#6E33FF', label = 'Brute Force, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[1], color = '#1D8BEC', label = 'Brute Force, 2048 Encoding', s = 90)
plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[0], color = '#6E33FF', label = 'Brute Force, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[1], color = '#1D8BEC', label = 'Brute Force, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[2], color = '#FF3030', label = 'ANNOY, Single Tree, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[3], color = '#FF7C7C', label = 'ANNOY, Single Tree, 2048 Encoding', s = 90)
plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[2], color = '#FF3030', label = 'ANNOY, Single Tree, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[3], color = '#FF7C7C', label = 'ANNOY, Single Tree, 2048 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[4], color = '#F35F0B', label = 'ANNOY, 10 Trees, 1000 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[5], color = '#F38B50', label = 'ANNOY, 10 Trees, 2048 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[6], color = '#E6DC04', label = 'ANNOY, 100 Trees, 1000 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[7], color = '#FFF524', label = 'ANNOY, 100 Trees, 2048 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[8], color = '#7EFF38', label = 'ANNOY, 1000 Trees, 1000 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[9], color = '#5ACA1D', label = 'ANNOY, 1000 Trees, 2048 Encoding', s = 90)
plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[2], color = '#FF3030', label = 'ANNOY, Single Tree, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[3], color = '#FF7C7C', label = 'ANNOY, Single Tree, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[4], color = '#F35F0B', label = 'ANNOY, 10 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[5], color = '#F38B50', label = 'ANNOY, 10 Trees, 2048 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[6], color = '#E6DC04', label = 'ANNOY, 100 Trees, 1000 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[7], color = '#FFF524', label = 'ANNOY, 100 Trees, 2048 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[8], color = '#7EFF38', label = 'ANNOY, 1000 Trees, 1000 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[9], color = '#5ACA1D', label = 'ANNOY, 1000 Trees, 2048 Encoding', s = 90)
plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[2], color = '#FF3030', label = 'ANNOY, Single Tree, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[3], color = '#FF7C7C', label = 'ANNOY, Single Tree, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[4], color = '#F35F0B', label = 'ANNOY, 10 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[5], color = '#F38B50', label = 'ANNOY, 10 Trees, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[6], color = '#E6DC04', label = 'ANNOY, 100 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[7], color = '#FFF524', label = 'ANNOY, 100 Trees, 2048 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[8], color = '#7EFF38', label = 'ANNOY, 1000 Trees, 1000 Encoding', s = 90)
# plt.scatter(['5', '10', '15', '20'], prec_compare[9], color = '#5ACA1D', label = 'ANNOY, 1000 Trees, 2048 Encoding', s = 90)
plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[2], color = '#FF3030', label = 'ANNOY, Single Tree, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[3], color = '#FF7C7C', label = 'ANNOY, Single Tree, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[4], color = '#F35F0B', label = 'ANNOY, 10 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[5], color = '#F38B50', label = 'ANNOY, 10 Trees, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[6], color = '#E6DC04', label = 'ANNOY, 100 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[7], color = '#FFF524', label = 'ANNOY, 100 Trees, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[8], color = '#7EFF38', label = 'ANNOY, 1000 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[9], color = '#5ACA1D', label = 'ANNOY, 1000 Trees, 2048 Encoding', s = 90)
plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
plt.clf()
plt.scatter(['5', '10', '15', '20'], prec_compare[2], color = '#FF3030', label = 'ANNOY, Single Tree, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[3], color = '#FF7C7C', label = 'ANNOY, Single Tree, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[4], color = '#F35F0B', label = 'ANNOY, 10 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[5], color = '#F38B50', label = 'ANNOY, 10 Trees, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[6], color = '#E6DC04', label = 'ANNOY, 100 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[7], color = '#FFF524', label = 'ANNOY, 100 Trees, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[8], color = '#7EFF38', label = 'ANNOY, 1000 Trees, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[9], color = '#5ACA1D', label = 'ANNOY, 1000 Trees, 2048 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[0], color = '#6E33FF', label = 'Brute Force, 1000 Encoding', s = 90)
plt.scatter(['5', '10', '15', '20'], prec_compare[1], color = '#1D8BEC', label = 'Brute Force, 2048 Encoding', s = 90)

plt.legend()
plt.title('Precision at Rank: Brute Force Nearest Neighbor')
plt.ylabel('Precision at Rank')
plt.xlabel('Rank (Returned Image Results)')
ax = plt.gca()
ax.set_ylim([.1, .9])
plt.show()

# %%
time_compare_1000 = time_compare[0::2]
time_compare_1000 = np.roll(time_compare_1000, shift = -1)

plt.clf()
plt.scatter(['ANNOY Single Tree', 'ANNOY 10 Trees', 'ANNOY 100 Trees', 'ANNOY 1000 Trees', 'Deterministic Baseline'], time_compare_1000, s = 90)
plt.ylabel('$log_{10}$(Average Runtime), Units: $log_{10}$(seconds)')
plt.xlabel('Nearest Neighbor Query Engine')
plt.title('Average Runtime by Nearest Neighbor Query Engine')
ax = plt.gca()
ax.set_yscale('log')
ax.set_ylim([0, 1])
plt.show()
# Out:
# <ipython-input-112-9112bf0e8cac>:11: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim([0, 1])

# %%
time_compare_1000 = time_compare[0::2]
time_compare_1000 = np.roll(time_compare_1000, shift = -1)

plt.clf()
plt.scatter(['ANNOY Single Tree', 'ANNOY 10 Trees', 'ANNOY 100 Trees', 'ANNOY 1000 Trees', 'Deterministic Baseline'], time_compare_1000*50000, s = 90)
plt.ylabel('$log_{10}$(Average Runtime), Units: $log_{10}$(seconds)')
plt.xlabel('Nearest Neighbor Query Engine')
plt.title('Average Runtime by Nearest Neighbor Query Engine')
ax = plt.gca()
ax.set_yscale('log')
# ax.set_ylim([0, 1])
plt.show()
